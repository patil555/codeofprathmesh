# %%
print("PRATHMESH")
# Out:
# PRATHMESH

# %%
print("Dept:=TE")
# Out:
# Dept:=TE

# %% [markdown]
# Electrical formulas used:
#
# • Series resistance: Rₛ = R₁ + R₂ + …
#
# • Parallel resistance: 1/Rₚ = 1/R₁ + 1/R₂ + …
#
# • Ohm’s Law: V = I × R
#
# Syntax
#
# • print() for output
#
# • input() for user input
#
# • float() for numeric conversion
#
# • Arithmetic operators: + − * /

# %% [markdown]
# Program to calculate equivalent resistance in series

# %%
r1=int(input("r1="))
r2=int(input("r2="))
rs=r1+r2
print("rs=",rs)
# Out:
# r1= 10
# r2= 05
# rs= 15

# %% [markdown]
# Program to calculate equivalent resistance in parallel

# %%
r1+float(input("r1="))
r2+float(input("r2="))
rp=1/(1/r1)+(1/r2)
print(rp)
# Out:
# r1= 55
# r2= 89
# 10.2

# %% [markdown]
# Program to calculate voltage using Ohm’s Law

# %%
i=float(input("i="))
r=float(input("i="))
v=i*r
print (v,"ohms")
# Out:
# i= 54
# i= 5
# 270.0 ohms

# %%
R1 = input("R1: ")
R2 = input("R2: ")
Rs = R1 + R2
print(Rs)
# Out:
# R1:  58
# R2:  9
# 589

# %%
R1 =int(input("R1: "))
R2 =int(input("R2: "))
Rs = R1 + R2
print(Rs)
# Out:
# R1:  45
# R2:  41
# 86

# %%
I = float(input("I: "))
R = float(input("R: "))
V = I * R
print(V)
# Out:
# I:  45
# R:  47
# 2115.0
